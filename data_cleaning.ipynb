# %%
import pandas as pd
import numpy as np

# %%
ratings = pd.read_csv('data/rating.csv', encoding= 'utf-8')
ratings.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %%
ratings = ratings.loc[ratings['rating'] != -1,:]
ratings.head()
# Out:
#      user_id  anime_id  rating
# 47         1      8074      10
# 81         1     11617      10
# 83         1     11757      10
# 101        1     15451      10
# 153        2     11771      10

# %%
len(ratings) #7.8 millones de entries (with rating: -1) & 6.33 millones (sin rating: -1)
len(ratings['user_id'].unique()) #73.515 usuarios  &  69600 usuarios (sin rating: -1)
ratings.groupby('user_id')['rating'].mean().mean() #mean rating for anime is 8.22
ratings.groupby('user_id')['rating'].agg(['count', 'mean', 'std'])
# Out:
#          count       mean       std
# user_id
# 1            4  10.000000  0.000000
# 2            1  10.000000       NaN
# 3           92   7.565217  1.549933
# 5          459   4.355120  2.381293
# 7          343   7.387755  1.104786
# ...        ...        ...       ...
# 73512       12   8.583333  1.564279
# 73513       33   7.515152  1.227834
# 73514        1  10.000000       NaN
# 73515      179   8.547486  1.137577
# 73516        2   9.000000  0.000000
#
# [69600 rows x 3 columns]

# %%
anime = pd.read_csv('data/anime.csv', encoding= 'utf-8')
anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
anime.loc[anime['name'] == 'Gintama',:]

anime.loc[anime['name'].str.contains('Shingeki no', regex=False),:]
# Out:
#        anime_id                                          name  \
# 86        16498                            Shingeki no Kyojin
# 125       25781           Shingeki no Kyojin: Kuinaki Sentaku
# 717       18397                        Shingeki no Kyojin OVA
# 920       21843                  Shingeki no Bahamut: Genesis
# 961       23777  Shingeki no Kyojin Movie 2: Jiyuu no Tsubasa
# 1069      23775   Shingeki no Kyojin Movie 1: Guren no Yumiya
# 3533      19285               Shingeki no Kyojin: Ano Hi Kara
# 4090      19391              Shingeki no Kyojin Picture Drama
# 6221      28447            Shingeki no Bahamut: Genesis Recap
# 10899     25777                   Shingeki no Kyojin Season 2
# 10928     31537          Shingeki no Bahamut: Manaria Friends
# 11076     30736              Shingeki no Bahamut: Virgin Soul
#
#                                                    genre     type episodes  \
# 86          Action, Drama, Fantasy, Shounen, Super Power       TV       25
# ...

# %%
anime['type'].unique()
# Out:
# array(['Movie', 'TV', 'OVA', 'Special', 'Music', 'ONA', nan], dtype=object)

# %%
anime.loc[(anime['members'] > 1000) & (anime['type'] == 'Movie'),:].sort_values('rating', ascending= False).head(20)
# Out:
#     anime_id                                               name  \
# 0      32281                                     Kimi no Na wa.
# 8      15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 11     28851                                     Koe no Katachi
# 15       199                      Sen to Chihiro no Kamikakushi
# 18     12355                       Ookami Kodomo no Ame to Yuki
# 24       164                                      Mononoke Hime
# 25      7311                      Suzumiya Haruhi no Shoushitsu
# 33     28957                Mushishi Zoku Shou: Suzu no Shizuku
# 35       431                                Howl no Ugoku Shiro
# 37     31757                    Kizumonogatari II: Nekketsu-hen
# 45      4282                     Kara no Kyoukai 5: Mujun Rasen
# 55      4565       Tengen Toppa Gurren Lagann Movie: Lagann-hen
# 59     11577         Steins;Gate Movie: Fuka Ryouiki no Déjà vu
# 60     10408                                 Hotarubi no Mori e
# ...
